# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt

# %% [markdown]
# Loading Audio Files

# %%
scale_file = "Data/test/test/TA_(1).mp3"

# %%
ipd.Audio(scale_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# load audio files with librosa
scale, sr = librosa.load(scale_file)

# %% [markdown]
# Mel filter banks

# %%
filter_banks = librosa.filters.mel(n_fft=2048, sr=22050, n_mels=10)

# %%
filter_banks.shape
# Out:
# (10, 1025)

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(filter_banks, 
                         sr=sr, 
                         x_axis="linear")
plt.colorbar(format="%+2.f")
plt.show()

# %% [markdown]
# Extracting Mel Spectrogram

# %%
mel_spectrogram = librosa.feature.melspectrogram(scale, sr=sr, n_fft=2048, hop_length=512, n_mels=10)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16204\2787548556.py:1: FutureWarning: Pass y=[-3.8707068e-07 -3.5913621e-07 -4.3722937e-07 ... -3.4092143e-02
#  -4.2796988e-02  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spectrogram = librosa.feature.melspectrogram(scale, sr=sr, n_fft=2048, hop_length=512, n_mels=10)

# %%
mel_spectrogram.shape
# Out:
# (10, 130)

# %%
log_mel_spectrogram = librosa.power_to_db(mel_spectrogram)

# %%
log_mel_spectrogram.shape
# Out:
# (10, 130)

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(log_mel_spectrogram, 
                         x_axis="time",
                         y_axis="mel", 
                         sr=sr)
plt.colorbar(format="%+2.f")
plt.show()

# %%
pip install librosa
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
